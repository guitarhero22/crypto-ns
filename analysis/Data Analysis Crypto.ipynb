# %%
import sys
sys.path.append("../")

# %% [markdown]
# ## Analysis of n - we are keeping mean time of arrival as 100 and T_k as 1000 milliseconds

# %%
import pandas as pd
mean_percent_longest_chain = []
mean_orphans_received = []
mean_blocks = []
x_axis = []

# %%
df = pd.read_csv("../final_results/results_1.dump")
df['percent_reaching_longest_chain'] = df['<in longest chain>']*100/df["<peer's blocks>"]
df
# Out:
#     Peer ID  <ComutePower>  <peer's blocks>  <in longest chain>  \
# 0         0              5                9                   1
# 1         1              5                7                   0
# 2         2              5               10                   7
# 3         3              5               13                   3
# 4         4              5                5                   0
# 5         5              5                9                   3
# 6         6              5                9                   4
# 7         7              5                9                   0
# 8         8              5               16                   6
# 9         9              5                7                   0
# 10       10              5                8                   2
# 11       11              5               11                   2
# 12       12              5                9                   2
# 13       13              5               22                   3
# 14       14              5               13                   4
# 15       15              5               13                   4
# 16       16              5               11                   0
# 17       17              5               16                   3
# 18       18              5               17                   1
# 19       19              5               14                   6
#
#     <% in longest chain>  <orphans received>  percent_reaching_longest_chain
# 0                3.22581                   4                       11.111111
# 1                0.00000                   3                        0.000000
# 2               21.21210                   2                       70.000000
# 3                9.67742                   2                       23.076923
# 4                0.00000                   3                        0.000000
# 5                9.37500                   3                       33.333333
# 6               12.90320                   4                       44.444444
# 7                0.00000                   3                        0.000000
# 8               19.35480                  10                       37.500000
# 9                0.00000                  10                        0.000000
# 10               6.25000                   5                       25.000000
# 11               6.45161                   7                       18.181818
# 12               6.45161                  11                       22.222222
# 13               9.67742                   8                       13.636364
# 14              12.90320                   6                       30.769231
# 15              13.33330                   4                       30.769231
# 16               0.00000                   9                        0.000000
# 17              10.00000                   8                       18.750000
# 18               3.22581                   8                        5.882353
# 19              19.35480                   6                       42.857143

# %%
mean_percent_longest_chain.append(df['percent_reaching_longest_chain'].mean())
mean_orphans_received.append(df['<orphans received>'].mean())
mean_blocks.append(df["<peer's blocks>"].mean())

# %%
x = 1000
x_axis.append(x)

# %% [markdown]
# ## When tk = 100000

# %%
df = pd.read_csv("../final_results/results_2.dump")
df['percent_reaching_longest_chain'] = df['<in longest chain>']*100/df["<peer's blocks>"]
df
# Out:
#     Peer ID  <ComutePower>  <peer's blocks>  <in longest chain>  \
# 0         0              5                0                   0
# 1         1              5                1                   0
# 2         2              5                2                   1
# 3         3              5                1                   1
# 4         4              5                0                   0
# 5         5              5                0                   0
# 6         6              5                1                   0
# 7         7              5                3                   3
# 8         8              5                2                   0
# 9         9              5                2                   2
# 10       10              5                0                   0
# 11       11              5                1                   1
# 12       12              5                1                   1
# 13       13              5                1                   0
# 14       14              5                0                   0
# 15       15              5                1                   1
# 16       16              5                2                   1
# 17       17              5                0                   0
# 18       18              5                2                   1
# 19       19              5                2                   0
#
#     <% in longest chain>  <orphans received>  percent_reaching_longest_chain
# 0                 0.0000                   0                             NaN
# 1                 0.0000                   0                             0.0
# 2                11.1111                   0                            50.0
# 3                10.0000                   0                           100.0
# 4                 0.0000                   0                             NaN
# 5                 0.0000                   0                             NaN
# 6                 0.0000                   0                             0.0
# 7                33.3333                   0                           100.0
# 8                 0.0000                   0                             0.0
# 9                22.2222                   0                           100.0
# 10                0.0000                   0                             NaN
# 11               11.1111                   0                           100.0
# 12               11.1111                   0                           100.0
# 13                0.0000                   0                             0.0
# 14                0.0000                   0                             NaN
# 15               11.1111                   0                           100.0
# 16               11.1111                   0                            50.0
# 17                0.0000                   0                             NaN
# 18               11.1111                   0                            50.0
# 19                0.0000                   0                             0.0

# %%
mean_percent_longest_chain.append(df['percent_reaching_longest_chain'].mean())
mean_orphans_received.append(df['<orphans received>'].mean())
mean_blocks.append(df["<peer's blocks>"].mean())

# %%
x = 10000
x_axis.append(x)

# %%
x = 100
x_axis.append(x)

# %%
df = pd.read_csv("../final_results/results_3.dump")
df['percent_reaching_longest_chain'] = df['<in longest chain>']*100/df["<peer's blocks>"]
df
# Out:
#     Peer ID  <ComutePower>  <peer's blocks>  <in longest chain>  \
# 0         0              5              110                  41
# 1         1              5              108                  10
# 2         2              5               92                  17
# 3         3              5              112                   5
# 4         4              5              108                   3
# 5         5              5               96                  12
# 6         6              5               91                   1
# 7         7              5              100                   0
# 8         8              5               96                   0
# 9         9              5               94                  16
# 10       10              5              100                   2
# 11       11              5               99                   1
# 12       12              5               98                   1
# 13       13              5              106                   7
# 14       14              5               90                   0
# 15       15              5               79                  10
# 16       16              5               99                  24
# 17       17              5              105                   2
# 18       18              5              108                  28
# 19       19              5              106                   3
#
#     <% in longest chain>  <orphans received>  percent_reaching_longest_chain
# 0              26.451600                 111                       37.272727
# 1               6.451610                 277                        9.259259
# 2              10.967700                 156                       18.478261
# 3               3.289470                 380                        4.464286
# 4               1.935480                 116                        2.777778
# 5               7.692310                 115                       12.500000
# 6               0.657895                 373                        1.098901
# 7               0.000000                 351                        0.000000
# 8               0.000000                 265                        0.000000
# 9              10.596000                 269                       17.021277
# 10              1.324500                 247                        2.000000
# 11              0.641026                 348                        1.010101
# 12              0.671141                 268                        1.020408
# 13              4.516130                  99                        6.603774
# 14              0.000000                 263                        0.000000
# 15              6.535950                 317                       12.658228
# 16             15.584400                 274                       24.242424
# 17              1.282050                 349                        1.904762
# 18             17.721500                 278                       25.925926
# 19              1.923080                 290                        2.830189

# %%
mean_percent_longest_chain.append(df['percent_reaching_longest_chain'].mean())
mean_orphans_received.append(df['<orphans received>'].mean())
mean_blocks.append(df["<peer's blocks>"].mean())

# %%
mean_percent_longest_chain = [mean_percent_longest_chain[i] for i in [2,0,1]]

# %%
mean_orphans_received = [mean_orphans_received[i] for i in [2, 0, 1]]

# %%
mean_blocks = [mean_blocks[i] for i in [2, 0, 1]]

# %%
mean_percent_longest_chain
# Out:
# [9.05341499734958, 21.376708667149842, 53.57142857142857]

# %%
from matplotlib  import pyplot as plt
plt.plot(x_axis, mean_percent_longest_chain, label = 'Mean of percent reaching longest chain')
plt.plot(x_axis, mean_orphans_received, label = 'Mean of orphans received')
plt.plot(x_axis, mean_blocks, label = 'Mean of number of blocks generateed')
plt.xlabel("T_k")
plt.ylabel("Property")
plt.title("Analysis of T_k")
plt.legend()
plt.show()

# %%
x_axis = [100,1000, 10000]
mean_percent_longest_chain[2] = 100

# %%
plt.plot(x_axis, mean_percent_longest_chain, label = 'Mean of percent reaching longest chain')
plt.plot(x_axis, mean_orphans_received, label = 'Mean of orphans received')
plt.plot(x_axis, mean_blocks, label = 'Mean of number of blocks generateed')
plt.xlabel("T_k")
plt.ylabel("Property")
plt.title("Analysis of T_k")
plt.legend()
plt.show()

# %%
mean_percent_longest_chain = []
mean_orphans_received = []
mean_blocks = []
x_axis = []

# %%
df = pd.read_csv("../final_results/results_4.dump")
df['percent_reaching_longest_chain'] = df['<in longest chain>']*100/df["<peer's blocks>"]
df
mean_percent_longest_chain.append(df['percent_reaching_longest_chain'].mean())
mean_orphans_received.append(df['<orphans received>'].mean())
mean_blocks.append(df["<peer's blocks>"].mean())
x_axis.append(0.25)

# %%
df
# Out:
#     Peer ID  <ComutePower>  <peer's blocks>  <in longest chain>  \
# 0         0       15.38460               11                   3
# 1         1       15.38460               11                   7
# 2         2       15.38460               13                   9
# 3         3       15.38460               13                   9
# 4         4       15.38460               11                   7
# 5         5        1.53846                1                   0
# 6         6        1.53846                0                   0
# 7         7        1.53846                1                   0
# 8         8        1.53846                1                   1
# 9         9        1.53846                1                   0
# 10       10        1.53846                2                   0
# 11       11        1.53846                1                   0
# 12       12        1.53846                2                   0
# 13       13        1.53846                2                   0
# 14       14        1.53846                0                   0
# 15       15        1.53846                0                   0
# 16       16        1.53846                1                   0
# 17       17        1.53846                1                   0
# 18       18        1.53846                0                   0
# 19       19        1.53846                1                   1
#
#     <% in longest chain>  <orphans received>  percent_reaching_longest_chain
# 0               10.71430                   1                       27.272727
# 1               24.13790                   1                       63.636364
# 2               31.03450                   0                       69.230769
# 3               31.03450                   4                       69.230769
# 4               24.13790                   0                       63.636364
# 5                0.00000                   3                        0.000000
# 6                0.00000                   3                             NaN
# 7                0.00000                   4                        0.000000
# 8                3.57143                   0                      100.000000
# 9                0.00000                   1                        0.000000
# 10               0.00000                   0                        0.000000
# 11               0.00000                   2                        0.000000
# 12               0.00000                   1                        0.000000
# 13               0.00000                   1                        0.000000
# 14               0.00000                   1                             NaN
# 15               0.00000                   1                             NaN
# 16               0.00000                   3                        0.000000
# 17               0.00000                   0                        0.000000
# 18               0.00000                   2                             NaN
# 19               3.57143                   2                      100.000000

# %%
df = pd.read_csv("../final_results/results_5.dump")
df['percent_reaching_longest_chain'] = df['<in longest chain>']*100/df["<peer's blocks>"]
mean_percent_longest_chain.append(df['percent_reaching_longest_chain'].mean())
mean_orphans_received.append(df['<orphans received>'].mean())
mean_blocks.append(df["<peer's blocks>"].mean())
x_axis.append(0.5)
df
# Out:
#     Peer ID  <ComutePower>  <peer's blocks>  <in longest chain>  \
# 0         0       9.090910               11                  10
# 1         1       9.090910                3                   0
# 2         2       9.090910                8                   3
# 3         3       9.090910                9                   1
# 4         4       9.090910                4                   0
# 5         5       9.090910               12                   8
# 6         6       9.090910                7                   3
# 7         7       9.090910               19                  14
# 8         8       9.090910                7                   2
# 9         9       9.090910                8                   2
# 10       10       0.909091                1                   0
# 11       11       0.909091                0                   0
# 12       12       0.909091                1                   0
# 13       13       0.909091                2                   0
# 14       14       0.909091                1                   0
# 15       15       0.909091                0                   0
# 16       16       0.909091                0                   0
# 17       17       0.909091                2                   0
# 18       18       0.909091                2                   1
# 19       19       0.909091                0                   0
#
#     <% in longest chain>  <orphans received>  percent_reaching_longest_chain
# 0               31.25000                   0                       90.909091
# 1                0.00000                   1                        0.000000
# 2               10.00000                   0                       37.500000
# 3                3.44828                   0                       11.111111
# 4                0.00000                   0                        0.000000
# 5               24.24240                   0                       66.666667
# 6               10.00000                   3                       42.857143
# 7               43.75000                   1                       73.684211
# 8                6.66667                   0                       28.571429
# 9                6.89655                   1                       25.000000
# 10               0.00000                   2                        0.000000
# 11               0.00000                   0                             NaN
# 12               0.00000                   1                        0.000000
# 13               0.00000                   0                        0.000000
# 14               0.00000                   0                        0.000000
# 15               0.00000                   2                             NaN
# 16               0.00000                   1                             NaN
# 17               0.00000                   0                        0.000000
# 18               3.33333                   0                       50.000000
# 19               0.00000                   0                             NaN

# %%
df = pd.read_csv("../final_results/results_6.dump")
df['percent_reaching_longest_chain'] = df['<in longest chain>']*100/df["<peer's blocks>"]
mean_percent_longest_chain.append(df['percent_reaching_longest_chain'].mean())
mean_orphans_received.append(df['<orphans received>'].mean())
mean_blocks.append(df["<peer's blocks>"].mean())
x_axis.append(0.5)
df
# Out:
#     Peer ID  <ComutePower>  <peer's blocks>  <in longest chain>  \
# 0         0       6.451610               12                   7
# 1         1       6.451610                7                   2
# 2         2       6.451610               12                   1
# 3         3       6.451610                3                   1
# 4         4       6.451610               20                  17
# 5         5       6.451610                7                   0
# 6         6       6.451610               14                   2
# 7         7       6.451610               11                   0
# 8         8       6.451610                6                   1
# 9         9       6.451610                9                   2
# 10       10       6.451610               11                   4
# 11       11       6.451610               11                   3
# 12       12       6.451610               11                   0
# 13       13       6.451610               11                   0
# 14       14       6.451610                8                   0
# 15       15       0.645161                2                   0
# 16       16       0.645161                0                   0
# 17       17       0.645161                3                   1
# 18       18       0.645161                0                   0
# 19       19       0.645161                0                   0
#
#     <% in longest chain>  <orphans received>  percent_reaching_longest_chain
# 0               21.21210                   0                       58.333333
# 1                5.88235                   2                       28.571429
# 2                2.94118                   3                        8.333333
# 3                3.03030                   0                       33.333333
# 4               51.51520                   1                       85.000000
# 5                0.00000                   7                        0.000000
# 6                6.06061                   2                       14.285714
# 7                0.00000                   2                        0.000000
# 8                2.94118                   0                       16.666667
# 9                6.06061                   3                       22.222222
# 10              12.50000                   1                       36.363636
# 11               8.82353                   3                       27.272727
# 12               0.00000                   0                        0.000000
# 13               0.00000                   6                        0.000000
# 14               0.00000                   9                        0.000000
# 15               0.00000                   0                        0.000000
# 16               0.00000                   0                             NaN
# 17               3.03030                   3                       33.333333
# 18               0.00000                  10                             NaN
# 19               0.00000                   0                             NaN

# %%
x_axis[2] = 0.75
plt.plot(x_axis, mean_percent_longest_chain, label = 'Mean of percent reaching longest chain')
plt.plot(x_axis, mean_orphans_received, label = 'Mean of orphans received')
plt.plot(x_axis, mean_blocks, label = 'Mean of number of blocks generateed')
plt.xlabel("% having lower mean time for T_k")
plt.ylabel("Property")
plt.title("Analysis of T_k")
plt.legend()
plt.show()

# %% [markdown]
# ## For % z

# %%
mean_percent_longest_chain = []
mean_orphans_received = []
mean_blocks = []
x_axis = []

# %%
df = pd.read_csv("../final_results/results_7.dump")
df['percent_reaching_longest_chain'] = df['<in longest chain>']*100/df["<peer's blocks>"]
df
mean_percent_longest_chain.append(df['percent_reaching_longest_chain'].mean())
mean_orphans_received.append(df['<orphans received>'].mean())
mean_blocks.append(df["<peer's blocks>"].mean())
x_axis.append(0.25)

# %%
df
# Out:
#     Peer ID  <ComutePower>  <peer's blocks>  <in longest chain>  \
# 0         0       9.090910                8                   5
# 1         1       9.090910                7                   1
# 2         2       9.090910                7                   5
# 3         3       9.090910               13                   5
# 4         4       9.090910                8                   2
# 5         5       9.090910               13                   1
# 6         6       9.090910               12                   6
# 7         7       9.090910               16                   0
# 8         8       9.090910               11                   6
# 9         9       9.090910               17                   4
# 10       10       0.909091                3                   1
# 11       11       0.909091                0                   0
# 12       12       0.909091                0                   0
# 13       13       0.909091                0                   0
# 14       14       0.909091                0                   0
# 15       15       0.909091                1                   0
# 16       16       0.909091                4                   0
# 17       17       0.909091                1                   0
# 18       18       0.909091                0                   0
# 19       19       0.909091                1                   0
#
#     <% in longest chain>  <orphans received>  percent_reaching_longest_chain
# 0               15.15150                   1                       62.500000
# 1                3.03030                   3                       14.285714
# 2               15.15150                   1                       71.428571
# 3               15.15150                   2                       38.461538
# 4                6.06061                   0                       25.000000
# 5                3.03030                   1                        7.692308
# 6               18.18180                   2                       50.000000
# 7                0.00000                   1                        0.000000
# 8               18.18180                   1                       54.545455
# 9               12.12120                   1                       23.529412
# 10               3.03030                   1                       33.333333
# 11               0.00000                   1                             NaN
# 12               0.00000                   2                             NaN
# 13               0.00000                   4                             NaN
# 14               0.00000                   4                             NaN
# 15               0.00000                   2                        0.000000
# 16               0.00000                   1                        0.000000
# 17               0.00000                   3                        0.000000
# 18               0.00000                   2                             NaN
# 19               0.00000                   1                        0.000000

# %%
df = pd.read_csv("../final_results/results_5.dump")
df['percent_reaching_longest_chain'] = df['<in longest chain>']*100/df["<peer's blocks>"]
mean_percent_longest_chain.append(df['percent_reaching_longest_chain'].mean())
mean_orphans_received.append(df['<orphans received>'].mean())
mean_blocks.append(df["<peer's blocks>"].mean())
x_axis.append(0.5)
df
# Out:
#     Peer ID  <ComutePower>  <peer's blocks>  <in longest chain>  \
# 0         0       9.090910               11                  10
# 1         1       9.090910                3                   0
# 2         2       9.090910                8                   3
# 3         3       9.090910                9                   1
# 4         4       9.090910                4                   0
# 5         5       9.090910               12                   8
# 6         6       9.090910                7                   3
# 7         7       9.090910               19                  14
# 8         8       9.090910                7                   2
# 9         9       9.090910                8                   2
# 10       10       0.909091                1                   0
# 11       11       0.909091                0                   0
# 12       12       0.909091                1                   0
# 13       13       0.909091                2                   0
# 14       14       0.909091                1                   0
# 15       15       0.909091                0                   0
# 16       16       0.909091                0                   0
# 17       17       0.909091                2                   0
# 18       18       0.909091                2                   1
# 19       19       0.909091                0                   0
#
#     <% in longest chain>  <orphans received>  percent_reaching_longest_chain
# 0               31.25000                   0                       90.909091
# 1                0.00000                   1                        0.000000
# 2               10.00000                   0                       37.500000
# 3                3.44828                   0                       11.111111
# 4                0.00000                   0                        0.000000
# 5               24.24240                   0                       66.666667
# 6               10.00000                   3                       42.857143
# 7               43.75000                   1                       73.684211
# 8                6.66667                   0                       28.571429
# 9                6.89655                   1                       25.000000
# 10               0.00000                   2                        0.000000
# 11               0.00000                   0                             NaN
# 12               0.00000                   1                        0.000000
# 13               0.00000                   0                        0.000000
# 14               0.00000                   0                        0.000000
# 15               0.00000                   2                             NaN
# 16               0.00000                   1                             NaN
# 17               0.00000                   0                        0.000000
# 18               3.33333                   0                       50.000000
# 19               0.00000                   0                             NaN

# %%
df = pd.read_csv("../final_results/results_6.dump")
df['percent_reaching_longest_chain'] = df['<in longest chain>']*100/df["<peer's blocks>"]
mean_percent_longest_chain.append(df['percent_reaching_longest_chain'].mean())
mean_orphans_received.append(df['<orphans received>'].mean())
mean_blocks.append(df["<peer's blocks>"].mean())
x_axis.append(0.5)
df
# Out:
#     Peer ID  <ComutePower>  <peer's blocks>  <in longest chain>  \
# 0         0       6.451610               12                   7
# 1         1       6.451610                7                   2
# 2         2       6.451610               12                   1
# 3         3       6.451610                3                   1
# 4         4       6.451610               20                  17
# 5         5       6.451610                7                   0
# 6         6       6.451610               14                   2
# 7         7       6.451610               11                   0
# 8         8       6.451610                6                   1
# 9         9       6.451610                9                   2
# 10       10       6.451610               11                   4
# 11       11       6.451610               11                   3
# 12       12       6.451610               11                   0
# 13       13       6.451610               11                   0
# 14       14       6.451610                8                   0
# 15       15       0.645161                2                   0
# 16       16       0.645161                0                   0
# 17       17       0.645161                3                   1
# 18       18       0.645161                0                   0
# 19       19       0.645161                0                   0
#
#     <% in longest chain>  <orphans received>  percent_reaching_longest_chain
# 0               21.21210                   0                       58.333333
# 1                5.88235                   2                       28.571429
# 2                2.94118                   3                        8.333333
# 3                3.03030                   0                       33.333333
# 4               51.51520                   1                       85.000000
# 5                0.00000                   7                        0.000000
# 6                6.06061                   2                       14.285714
# 7                0.00000                   2                        0.000000
# 8                2.94118                   0                       16.666667
# 9                6.06061                   3                       22.222222
# 10              12.50000                   1                       36.363636
# 11               8.82353                   3                       27.272727
# 12               0.00000                   0                        0.000000
# 13               0.00000                   6                        0.000000
# 14               0.00000                   9                        0.000000
# 15               0.00000                   0                        0.000000
# 16               0.00000                   0                             NaN
# 17               3.03030                   3                       33.333333
# 18               0.00000                  10                             NaN
# 19               0.00000                   0                             NaN

# %%
x_axis[2] = 0.75
plt.plot(x_axis, mean_percent_longest_chain, label = 'Mean of percent reaching longest chain')
plt.plot(x_axis, mean_orphans_received, label = 'Mean of orphans received')
plt.plot(x_axis, mean_blocks, label = 'Mean of number of blocks generateed')
plt.xlabel("% having lower mean time for T_k")
plt.ylabel("Property")
plt.title("Analysis of T_k")
plt.legend()
plt.show()

# %%
mean_percent_longest_chain = []
mean_orphans_received = []
mean_blocks = []
x_axis = []

# %%
df = pd.read_csv("../final_results/results_4.dump")
df['percent_reaching_longest_chain'] = df['<in longest chain>']*100/df["<peer's blocks>"]
df
mean_percent_longest_chain.append(df['percent_reaching_longest_chain'].mean())
mean_orphans_received.append(df['<orphans received>'].mean())
mean_blocks.append(df["<peer's blocks>"].mean())
x_axis.append(0.25)

# %%
df
# Out:
#     Peer ID  <ComutePower>  <peer's blocks>  <in longest chain>  \
# 0         0       15.38460               11                   3
# 1         1       15.38460               11                   7
# 2         2       15.38460               13                   9
# 3         3       15.38460               13                   9
# 4         4       15.38460               11                   7
# 5         5        1.53846                1                   0
# 6         6        1.53846                0                   0
# 7         7        1.53846                1                   0
# 8         8        1.53846                1                   1
# 9         9        1.53846                1                   0
# 10       10        1.53846                2                   0
# 11       11        1.53846                1                   0
# 12       12        1.53846                2                   0
# 13       13        1.53846                2                   0
# 14       14        1.53846                0                   0
# 15       15        1.53846                0                   0
# 16       16        1.53846                1                   0
# 17       17        1.53846                1                   0
# 18       18        1.53846                0                   0
# 19       19        1.53846                1                   1
#
#     <% in longest chain>  <orphans received>  percent_reaching_longest_chain
# 0               10.71430                   1                       27.272727
# 1               24.13790                   1                       63.636364
# 2               31.03450                   0                       69.230769
# 3               31.03450                   4                       69.230769
# 4               24.13790                   0                       63.636364
# 5                0.00000                   3                        0.000000
# 6                0.00000                   3                             NaN
# 7                0.00000                   4                        0.000000
# 8                3.57143                   0                      100.000000
# 9                0.00000                   1                        0.000000
# 10               0.00000                   0                        0.000000
# 11               0.00000                   2                        0.000000
# 12               0.00000                   1                        0.000000
# 13               0.00000                   1                        0.000000
# 14               0.00000                   1                             NaN
# 15               0.00000                   1                             NaN
# 16               0.00000                   3                        0.000000
# 17               0.00000                   0                        0.000000
# 18               0.00000                   2                             NaN
# 19               3.57143                   2                      100.000000

# %%
df = pd.read_csv("../final_results/results_5.dump")
df['percent_reaching_longest_chain'] = df['<in longest chain>']*100/df["<peer's blocks>"]
mean_percent_longest_chain.append(df['percent_reaching_longest_chain'].mean())
mean_orphans_received.append(df['<orphans received>'].mean())
mean_blocks.append(df["<peer's blocks>"].mean())
x_axis.append(0.5)
df
# Out:
#     Peer ID  <ComutePower>  <peer's blocks>  <in longest chain>  \
# 0         0       9.090910               11                  10
# 1         1       9.090910                3                   0
# 2         2       9.090910                8                   3
# 3         3       9.090910                9                   1
# 4         4       9.090910                4                   0
# 5         5       9.090910               12                   8
# 6         6       9.090910                7                   3
# 7         7       9.090910               19                  14
# 8         8       9.090910                7                   2
# 9         9       9.090910                8                   2
# 10       10       0.909091                1                   0
# 11       11       0.909091                0                   0
# 12       12       0.909091                1                   0
# 13       13       0.909091                2                   0
# 14       14       0.909091                1                   0
# 15       15       0.909091                0                   0
# 16       16       0.909091                0                   0
# 17       17       0.909091                2                   0
# 18       18       0.909091                2                   1
# 19       19       0.909091                0                   0
#
#     <% in longest chain>  <orphans received>  percent_reaching_longest_chain
# 0               31.25000                   0                       90.909091
# 1                0.00000                   1                        0.000000
# 2               10.00000                   0                       37.500000
# 3                3.44828                   0                       11.111111
# 4                0.00000                   0                        0.000000
# 5               24.24240                   0                       66.666667
# 6               10.00000                   3                       42.857143
# 7               43.75000                   1                       73.684211
# 8                6.66667                   0                       28.571429
# 9                6.89655                   1                       25.000000
# 10               0.00000                   2                        0.000000
# 11               0.00000                   0                             NaN
# 12               0.00000                   1                        0.000000
# 13               0.00000                   0                        0.000000
# 14               0.00000                   0                        0.000000
# 15               0.00000                   2                             NaN
# 16               0.00000                   1                             NaN
# 17               0.00000                   0                        0.000000
# 18               3.33333                   0                       50.000000
# 19               0.00000                   0                             NaN

# %%
df = pd.read_csv("../final_results/results_6.dump")
df['percent_reaching_longest_chain'] = df['<in longest chain>']*100/df["<peer's blocks>"]
mean_percent_longest_chain.append(df['percent_reaching_longest_chain'].mean())
mean_orphans_received.append(df['<orphans received>'].mean())
mean_blocks.append(df["<peer's blocks>"].mean())
x_axis.append(0.5)
df
# Out:
#     Peer ID  <ComutePower>  <peer's blocks>  <in longest chain>  \
# 0         0       6.451610               12                   7
# 1         1       6.451610                7                   2
# 2         2       6.451610               12                   1
# 3         3       6.451610                3                   1
# 4         4       6.451610               20                  17
# 5         5       6.451610                7                   0
# 6         6       6.451610               14                   2
# 7         7       6.451610               11                   0
# 8         8       6.451610                6                   1
# 9         9       6.451610                9                   2
# 10       10       6.451610               11                   4
# 11       11       6.451610               11                   3
# 12       12       6.451610               11                   0
# 13       13       6.451610               11                   0
# 14       14       6.451610                8                   0
# 15       15       0.645161                2                   0
# 16       16       0.645161                0                   0
# 17       17       0.645161                3                   1
# 18       18       0.645161                0                   0
# 19       19       0.645161                0                   0
#
#     <% in longest chain>  <orphans received>  percent_reaching_longest_chain
# 0               21.21210                   0                       58.333333
# 1                5.88235                   2                       28.571429
# 2                2.94118                   3                        8.333333
# 3                3.03030                   0                       33.333333
# 4               51.51520                   1                       85.000000
# 5                0.00000                   7                        0.000000
# 6                6.06061                   2                       14.285714
# 7                0.00000                   2                        0.000000
# 8                2.94118                   0                       16.666667
# 9                6.06061                   3                       22.222222
# 10              12.50000                   1                       36.363636
# 11               8.82353                   3                       27.272727
# 12               0.00000                   0                        0.000000
# 13               0.00000                   6                        0.000000
# 14               0.00000                   9                        0.000000
# 15               0.00000                   0                        0.000000
# 16               0.00000                   0                             NaN
# 17               3.03030                   3                       33.333333
# 18               0.00000                  10                             NaN
# 19               0.00000                   0                             NaN

# %%
x_axis[2] = 0.75
plt.plot(x_axis, mean_percent_longest_chain, label = 'Mean of percent reaching longest chain')
plt.plot(x_axis, mean_orphans_received, label = 'Mean of orphans received')
plt.plot(x_axis, mean_blocks, label = 'Mean of number of blocks generateed')
plt.xlabel("% having lower mean time for T_k")
plt.ylabel("Property")
plt.title("Analysis of T_k")
plt.legend()
plt.show()

# %%
mean_percent_longest_chain = []
mean_orphans_received = []
mean_blocks = []
x_axis = []

# %%
df = pd.read_csv("../final_results/results_10.dump")
df['percent_reaching_longest_chain'] = df['<in longest chain>']*100/df["<peer's blocks>"]
df
mean_percent_longest_chain.append(df['percent_reaching_longest_chain'].mean())
mean_orphans_received.append(df['<orphans received>'].mean())
mean_blocks.append(df["<peer's blocks>"].mean())
x_axis.append(10)

# %%
df
# Out:
#    Peer ID  <ComutePower>  <peer's blocks>  <in longest chain>  \
# 0        0       18.18180                5                   2
# 1        1       18.18180               10                   7
# 2        2       18.18180               10                   7
# 3        3       18.18180                9                   6
# 4        4       18.18180                6                   2
# 5        5        1.81818                1                   0
# 6        6        1.81818                0                   0
# 7        7        1.81818                1                   0
# 8        8        1.81818                0                   0
# 9        9        1.81818                4                   1
#
#    <% in longest chain>  <orphans received>  percent_reaching_longest_chain
# 0               8.69565                   0                       40.000000
# 1              30.43480                   0                       70.000000
# 2              30.43480                   0                       70.000000
# 3              26.08700                   0                       66.666667
# 4               9.09091                   0                       33.333333
# 5               0.00000                   0                        0.000000
# 6               0.00000                   1                             NaN
# 7               0.00000                   0                        0.000000
# 8               0.00000                   0                             NaN
# 9               4.34783                   0                       25.000000

# %%
df = pd.read_csv("../final_results/results_11.dump")
df['percent_reaching_longest_chain'] = df['<in longest chain>']*100/df["<peer's blocks>"]
mean_percent_longest_chain.append(df['percent_reaching_longest_chain'].mean())
mean_orphans_received.append(df['<orphans received>'].mean())
mean_blocks.append(df["<peer's blocks>"].mean())
x_axis.append(100)
df
# Out:
#     Peer ID  <ComutePower>  <peer's blocks>  <in longest chain>  \
# 0         0       1.818180               10                   0
# 1         1       1.818180                7                   0
# 2         2       1.818180               14                   7
# 3         3       1.818180                6                   1
# 4         4       1.818180               13                   0
# ..      ...            ...              ...                 ...
# 95       95       0.181818                3                   0
# 96       96       0.181818                1                   0
# 97       97       0.181818                3                   0
# 98       98       0.181818                0                   0
# 99       99       0.181818                1                   0
#
#     <% in longest chain>  <orphans received>  percent_reaching_longest_chain
# 0                  0.000                  27                        0.000000
# 1                  0.000                  15                        0.000000
# 2                 21.875                  21                       50.000000
# 3                  3.125                  25                       16.666667
# 4                  0.000                  21                        0.000000
# ..                   ...                 ...                             ...
# 95                 0.000                  21                        0.000000
# 96                 0.000                  43                        0.000000
# 97                 0.000                  37                        0.000000
# 98                 0.000                  16                             NaN
# 99                 0.000                  20                        0.000000
#
# [100 rows x 7 columns]

# %%
df = pd.read_csv("../final_results/results_12.dump")
df['percent_reaching_longest_chain'] = df['<in longest chain>']*100/df["<peer's blocks>"]
mean_percent_longest_chain.append(df['percent_reaching_longest_chain'].mean())
mean_orphans_received.append(df['<orphans received>'].mean())
mean_blocks.append(df["<peer's blocks>"].mean())
x_axis.append(50)
df
# Out:
#     Peer ID  <ComutePower>  <peer's blocks>  <in longest chain>  \
# 0         0       3.636360               12                   0
# 1         1       3.636360                4                   0
# 2         2       3.636360               14                   4
# 3         3       3.636360                8                   2
# 4         4       3.636360               16                   6
# 5         5       0.363636                0                   0
# 6         6       0.363636                2                   1
# 7         7       0.363636                0                   0
# 8         8       0.363636                3                   0
# 9         9       0.363636                0                   0
# 10       10       3.636360               14                   4
# 11       11       3.636360                6                   0
# 12       12       3.636360               17                  11
# 13       13       3.636360               11                   2
# 14       14       3.636360                9                   4
# 15       15       0.363636                0                   0
# 16       16       0.363636                1                   0
# 17       17       0.363636                0                   0
# 18       18       0.363636                1                   0
# 19       19       0.363636                0                   0
# 20       20       3.636360               14                   4
# 21       21       3.636360               10                   0
# 22       22       3.636360                1                   0
# 23       23       3.636360               10                   5
# 24       24       3.636360                9                   2
# 25       25       0.363636                2                   0
# 26       26       0.363636                2                   0
# 27       27       0.363636                2                   0
# 28       28       0.363636                1                   0
# 29       29       0.363636                0                   0
# 30       30       3.636360                5                   0
# 31       31       3.636360                9                   3
# 32       32       3.636360               11                   0
# 33       33       3.636360               10                   5
# 34       34       3.636360                8                   0
# 35       35       0.363636                2                   0
# 36       36       0.363636                1                   0
# 37       37       0.363636                2                   1
# 38       38       0.363636                0                   0
# 39       39       0.363636                0                   0
# 40       40       3.636360                6                   0
# 41       41       3.636360                6                   1
# 42       42       3.636360               12                   1
# 43       43       3.636360               13                   0
# 44       44       3.636360                7                   0
# 45       45       0.363636                0                   0
# 46       46       0.363636                2                   0
# 47       47       0.363636                1                   0
# 48       48       0.363636                2                   0
# 49       49       0.363636                2                   0
#
#     <% in longest chain>  <orphans received>  percent_reaching_longest_chain
# 0                0.00000                  10                        0.000000
# 1                0.00000                   7                        0.000000
# 2               13.79310                  12                       28.571429
# 3                6.89655                   9                       25.000000
# 4               20.68970                  11                       37.500000
# 5                0.00000                   9                             NaN
# 6                3.44828                  12                       50.000000
# 7                0.00000                  10                             NaN
# 8                0.00000                  13                        0.000000
# 9                0.00000                  12                             NaN
# 10              15.38460                  10                       28.571429
# 11               0.00000                  10                        0.000000
# 12              39.28570                  11                       64.705882
# 13               6.45161                   7                       18.181818
# 14              13.79310                   6                       44.444444
# 15               0.00000                  10                             NaN
# 16               0.00000                  10                        0.000000
# 17               0.00000                  12                             NaN
# 18               0.00000                   7                        0.000000
# 19               0.00000                  11                             NaN
# 20              13.33330                  10                       28.571429
# 21               0.00000                   8                        0.000000
# 22               0.00000                  12                        0.000000
# 23              17.85710                  21                       50.000000
# 24               6.89655                   7                       22.222222
# 25               0.00000                  14                        0.000000
# 26               0.00000                  13                        0.000000
# 27               0.00000                  12                        0.000000
# 28               0.00000                  15                        0.000000
# 29               0.00000                  10                             NaN
# 30               0.00000                  16                        0.000000
# 31              11.11110                   9                       33.333333
# 32               0.00000                   8                        0.000000
# 33              17.85710                   7                       50.000000
# 34               0.00000                   6                        0.000000
# 35               0.00000                  15                        0.000000
# 36               0.00000                  14                        0.000000
# 37               3.70370                  15                       50.000000
# 38               0.00000                  16                             NaN
# 39               0.00000                   7                             NaN
# 40               0.00000                  10                        0.000000
# 41               3.44828                   9                       16.666667
# 42               3.57143                  23                        8.333333
# 43               0.00000                  10                        0.000000
# 44               0.00000                  10                        0.000000
# 45               0.00000                  15                             NaN
# 46               0.00000                   7                        0.000000
# 47               0.00000                  11                        0.000000
# 48               0.00000                  11                        0.000000
# 49               0.00000                  11                        0.000000

# %%
plt.plot(x_axis, mean_percent_longest_chain, label = 'Mean of percent reaching longest chain')
plt.plot(x_axis, mean_orphans_received, label = 'Mean of orphans received')
plt.plot(x_axis, mean_blocks, label = 'Mean of number of blocks generateed')
plt.xlabel("N")
plt.ylabel("Property")
plt.title("Value of n")
plt.legend()
plt.show()
