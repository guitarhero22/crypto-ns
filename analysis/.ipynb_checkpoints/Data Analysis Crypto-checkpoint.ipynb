# %%
import sys
sys.path.append("../")

# %% [markdown]
# ## Analysis of n - we are keeping mean time of arrival as 100 and T_k as 1000 milliseconds

# %%
import pandas as pd
mean_percent_longest_chain = []
mean_orphans_received = []
mean_blocks = []
x_axis = []

# %%
df = pd.read_csv("../dumps/results.dump")
df
# Out:
#     Peer ID  <ComutePower>  <peer's blocks>  <in longest chain>  \
# 0         0              5               10                   0
# 1         1              5               14                   2
# 2         2              5               13                   6
# 3         3              5               14                   7
# 4         4              5                9                   3
# 5         5              5               10                   0
# 6         6              5               13                   7
# 7         7              5               10                   1
# 8         8              5               12                   3
# 9         9              5               10                   0
# 10       10              5               17                  10
# 11       11              5                7                   3
# 12       12              5                8                   0
# 13       13              5                4                   0
# 14       14              5               11                   5
# 15       15              5                6                   2
# 16       16              5                6                   0
# 17       17              5                8                   0
# 18       18              5               11                   1
# 19       19              5                8                   0
#
#     <% in longest chain>  <orphans received>
# 0                0.00000                   5
# 1                5.26316                   5
# 2               15.78950                   4
# 3               17.94870                   7
# 4                7.69231                   6
# 5                0.00000                   7
# 6               17.94870                   6
# 7                2.50000                  11
# 8                7.50000                   8
# 9                0.00000                   7
# 10              25.64100                   6
# 11               7.89474                  10
# 12               0.00000                  12
# 13               0.00000                  16
# 14              12.82050                   8
# 15               5.26316                   4
# 16               0.00000                   8
# 17               0.00000                   5
# 18               2.56410                   9
# 19               0.00000                  11

# %%
mean_percent_longest_chain.append(df['<% in longest chain>'].mean())
mean_orphans_received.append(df['<orphans received>'].mean())
mean_blocks.append(df["<peer's blocks>"].mean())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.pyenv/versions/3.7.9/envs/crypto-analysis/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/.pyenv/versions/3.7.9/envs/crypto-analysis/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/.pyenv/versions/3.7.9/envs/crypto-analysis/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: "peer's blocks"
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_402024/3733150647.py in <module>
#       1 mean_percent_longest_chain.append(df['<% in longest chain>'].mean())
#       2 mean_orphans_received.append(df['<orphans received>'].mean())
# ----> 3 mean_blocks.append(df["peer's blocks"].mean())
#
# ~/.pyenv/versions/3.7.9/envs/crypto-analysis/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3453             if self.columns.nlevels > 1:
#    3454                 return self._getitem_multilevel(key)
# -> 3455             indexer = self.columns.get_loc(key)
#    3456             if is_integer(indexer):
#    3457                 indexer = [indexer]
#
# ~/.pyenv/versions/3.7.9/envs/crypto-analysis/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: "peer's blocks"

# %%
x = 10000
x_axis.append(x)
